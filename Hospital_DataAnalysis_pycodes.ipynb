# %%
# Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.dates as mdates

# %%
# Load Data
df = pd.read_excel(r"C:\Users\majaz\OneDrive\Desktop\Hospital_project\2.RAW_DATA.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0           Unnamed: 1                            Unnamed: 2  \
# 0         NaN                Month  Average Licensed Bed  Occupancy Rate
# 1         NaN  2020-01-01 00:00:00                                  0.96
# 2         NaN  2020-02-01 00:00:00                                  0.96
# 3         NaN  2020-03-01 00:00:00                                  0.81
# 4         NaN  2020-04-01 00:00:00                                  0.94
#
#                                     Unnamed: 3  \
# 0  Unassisted Fall Rate per 1,000 Patient Days
# 1                                         2.21
# 2                                         1.79
# 3                                         1.03
# 4                                         1.97
#
#                                   Unnamed: 4         Unnamed: 5  \
# 0  Staff Responsiveness Domain Top Box Score  Unassisted Fall %
# 1                                      68.34              0.221
# 2                                      72.75              0.179
# 3                                      67.07              0.103
# 4                                      71.21              0.197
#
#                                     Unnamed: 6  \
# 0  Staff Responsiveness Domain Top Box Score %
# 1                                       0.6834
# 2                                       0.7275
# 3                                       0.6707
# 4                                       0.7121
#
#                                      Unnamed: 7
# 0  Staff Responsiveness Top Box Score Benchmark
# 1                                            65
# 2                                            65
# 3                                            65
# 4                                            65

# %%
# Load Data
df = pd.read_excel(
    r"C:\Users\majaz\OneDrive\Desktop\Hospital_project\2.RAW_DATA.xlsx",
    sheet_name="Case Study Dataset",
    header=1
)

# %%
df.head()
# Out:
#    Unnamed: 0      Month  Average Licensed Bed  Occupancy Rate  \
# 0         NaN 2020-01-01                                  0.96
# 1         NaN 2020-02-01                                  0.96
# 2         NaN 2020-03-01                                  0.81
# 3         NaN 2020-04-01                                  0.94
# 4         NaN 2020-05-01                                  1.01
#
#    Unassisted Fall Rate per 1,000 Patient Days  \
# 0                                         2.21
# 1                                         1.79
# 2                                         1.03
# 3                                         1.97
# 4                                         3.41
#
#    Staff Responsiveness Domain Top Box Score  Unassisted Fall %  \
# 0                                      68.34              0.221
# 1                                      72.75              0.179
# 2                                      67.07              0.103
# 3                                      71.21              0.197
# 4                                      57.68              0.341
#
#    Staff Responsiveness Domain Top Box Score %  \
# 0                                       0.6834
# 1                                       0.7275
# 2                                       0.6707
# 3                                       0.7121
# 4                                       0.5768
#
#    Staff Responsiveness Top Box Score Benchmark
# 0                                            65
# 1                                            65
# 2                                            65
# 3                                            65
# 4                                            65

# %%
df.shape
# Out:
# (60, 8)

# %% [markdown]
# # Data Cleaning and Preparation

# %% [markdown]
# ## Basic check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    0 non-null      float64
#  1   Month                                         60 non-null     datetime64[ns]
#  2   Average Licensed Bed  Occupancy Rate          60 non-null     float64
#  3   Unassisted Fall Rate per 1,000 Patient Days   60 non-null     float64
#  4   Staff Responsiveness Domain Top Box Score     60 non-null     float64
#  5   Unassisted Fall %                             60 non-null     float64
#  6   Staff Responsiveness Domain Top Box Score %   60 non-null     float64
#  7   Staff Responsiveness Top Box Score Benchmark  60 non-null     int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 3.9 KB

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df
# Out:
#         Month  Average Licensed Bed  Occupancy Rate  \
# 0  2020-01-01                                  0.96
# 1  2020-02-01                                  0.96
# 2  2020-03-01                                  0.81
# 3  2020-04-01                                  0.94
# 4  2020-05-01                                  1.01
# 5  2020-06-01                                  0.98
# 6  2020-07-01                                  0.95
# 7  2020-08-01                                  0.94
# 8  2020-09-01                                  0.95
# 9  2020-10-01                                  0.92
# 10 2020-11-01                                  0.95
# 11 2020-12-01                                  0.98
# 12 2021-01-01                                  1.00
# 13 2021-02-01                                  0.99
# 14 2021-03-01                                  0.95
# 15 2021-04-01                                  0.96
# 16 2021-05-01                                  0.94
# 17 2021-06-01                                  0.94
# 18 2021-07-01                                  0.94
# 19 2021-08-01                                  0.93
# 20 2021-09-01                                  0.97
# 21 2021-10-01                                  0.95
# 22 2021-11-01                                  0.96
# 23 2021-12-01                                  0.98
# 24 2022-01-01                                  1.01
# 25 2022-02-01                                  0.99
# 26 2022-03-01                                  0.96
# 27 2022-04-01                                  0.96
# 28 2022-05-01                                  0.95
# 29 2022-06-01                                  0.95
# 30 2022-07-01                                  0.96
# 31 2022-08-01                                  0.96
# 32 2022-09-01                                  0.95
# 33 2022-10-01                                  0.96
# 34 2022-11-01                                  0.97
# 35 2022-12-01                                  0.98
# 36 2023-01-01                                  0.99
# 37 2023-02-01                                  0.99
# 38 2023-03-01                                  0.98
# 39 2023-04-01                                  0.96
# 40 2023-05-01                                  0.94
# 41 2023-06-01                                  0.96
# 42 2023-07-01                                  0.95
# 43 2023-08-01                                  0.95
# 44 2023-09-01                                  0.98
# 45 2023-10-01                                  0.98
# 46 2023-11-01                                  0.99
# 47 2023-12-01                                  0.99
# 48 2024-01-01                                  0.99
# 49 2024-02-01                                  0.98
# 50 2024-03-01                                  0.94
# 51 2024-04-01                                  0.95
# 52 2024-05-01                                  0.95
# 53 2024-06-01                                  0.95
# 54 2024-07-01                                  0.96
# 55 2024-08-01                                  0.96
# 56 2024-09-01                                  0.97
# 57 2024-10-01                                  0.98
# 58 2024-11-01                                  0.98
# 59 2024-12-01                                  1.00
#
#     Unassisted Fall Rate per 1,000 Patient Days  \
# 0                                          2.21
# 1                                          1.79
# 2                                          1.03
# 3                                          1.97
# 4                                          3.41
# 5                                          2.61
# 6                                          2.42
# 7                                          2.09
# 8                                          3.11
# 9                                          1.60
# 10                                         2.31
# 11                                         2.47
# 12                                         3.03
# 13                                         2.35
# 14                                         2.47
# 15                                         1.94
# 16                                         2.54
# 17                                         3.17
# 18                                         2.79
# 19                                         2.05
# 20                                         3.34
# 21                                         2.44
# 22                                         2.31
# 23                                         2.57
# 24                                         3.33
# 25                                         3.19
# 26                                         2.78
# 27                                         2.91
# 28                                         2.49
# 29                                         2.31
# 30                                         2.43
# 31                                         3.13
# 32                                         2.81
# 33                                         2.07
# 34                                         3.11
# 35                                         3.21
# 36                                         3.17
# 37                                         3.39
# 38                                         3.03
# 39                                         2.73
# 40                                         2.89
# 41                                         2.55
# 42                                         2.42
# 43                                         2.03
# 44                                         2.56
# 45                                         3.07
# 46                                         2.99
# 47                                         3.03
# 48                                         3.09
# 49                                         3.15
# 50                                         2.33
# 51                                         2.01
# 52                                         1.79
# 53                                         1.98
# 54                                         2.51
# 55                                         2.63
# 56                                         2.71
# 57                                         2.97
# 58                                         2.84
# 59                                         2.81
#
#     Staff Responsiveness Domain Top Box Score  Unassisted Fall %  \
# 0                                       68.34              0.221
# 1                                       72.75              0.179
# 2                                       67.07              0.103
# 3                                       71.21              0.197
# 4                                       57.68              0.341
# 5                                       67.86              0.261
# 6                                       66.09              0.242
# 7                                       70.38              0.209
# 8                                       53.31              0.311
# 9                                       67.55              0.160
# 10                                      60.35              0.231
# 11                                      61.33              0.247
# 12                                      61.06              0.303
# 13                                      65.23              0.235
# 14                                      64.02              0.247
# 15                                      70.11              0.194
# 16                                      68.16              0.254
# 17                                      54.38              0.317
# 18                                      64.00              0.279
# 19                                      66.13              0.205
# 20                                      55.17              0.334
# 21                                      64.03              0.244
# 22                                      64.12              0.231
# 23                                      60.42              0.257
# 24                                      58.41              0.333
# 25                                      59.77              0.319
# 26                                      61.32              0.278
# 27                                      60.18              0.291
# 28                                      63.07              0.249
# 29                                      63.11              0.231
# 30                                      61.03              0.243
# 31                                      59.97              0.313
# 32                                      61.53              0.281
# 33                                      64.16              0.207
# 34                                      57.29              0.311
# 35                                      57.18              0.321
# 36                                      58.22              0.317
# 37                                      57.12              0.339
# 38                                      59.45              0.303
# 39                                      62.57              0.273
# 40                                      62.89              0.289
# 41                                      63.69              0.255
# 42                                      64.93              0.242
# 43                                      66.77              0.203
# 44                                      65.96              0.256
# 45                                      60.44              0.307
# 46                                      61.76              0.299
# 47                                      60.32              0.303
# 48                                      60.67              0.309
# 49                                      59.14              0.315
# 50                                      63.55              0.233
# 51                                      66.19              0.201
# 52                                      67.01              0.179
# 53                                      66.53              0.198
# 54                                      65.87              0.251
# 55                                      65.46              0.263
# 56                                      65.71              0.271
# 57                                      64.02              0.297
# 58                                      64.13              0.284
# 59                                      65.08              0.281
#
#     Staff Responsiveness Domain Top Box Score %  \
# 0                                        0.6834
# 1                                        0.7275
# 2                                        0.6707
# 3                                        0.7121
# 4                                        0.5768
# 5                                        0.6786
# 6                                        0.6609
# 7                                        0.7038
# 8                                        0.5331
# 9                                        0.6755
# 10                                       0.6035
# 11                                       0.6133
# 12                                       0.6106
# 13                                       0.6523
# 14                                       0.6402
# 15                                       0.7011
# 16                                       0.6816
# 17                                       0.5438
# 18                                       0.6400
# 19                                       0.6613
# 20                                       0.5517
# 21                                       0.6403
# 22                                       0.6412
# 23                                       0.6042
# 24                                       0.5841
# 25                                       0.5977
# 26                                       0.6132
# 27                                       0.6018
# 28                                       0.6307
# 29                                       0.6311
# 30                                       0.6103
# 31                                       0.5997
# 32                                       0.6153
# 33                                       0.6416
# 34                                       0.5729
# 35                                       0.5718
# 36                                       0.5822
# 37                                       0.5712
# 38                                       0.5945
# 39                                       0.6257
# 40                                       0.6289
# 41                                       0.6369
# 42                                       0.6493
# 43                                       0.6677
# 44                                       0.6596
# 45                                       0.6044
# 46                                       0.6176
# 47                                       0.6032
# 48                                       0.6067
# 49                                       0.5914
# 50                                       0.6355
# 51                                       0.6619
# 52                                       0.6701
# 53                                       0.6653
# 54                                       0.6587
# 55                                       0.6546
# 56                                       0.6571
# 57                                       0.6402
# 58                                       0.6413
# 59                                       0.6508
#
#     Staff Responsiveness Top Box Score Benchmark
# 0                                             65
# 1                                             65
# 2                                             65
# 3                                             65
# 4                                             65
# 5                                             65
# 6                                             65
# 7                                             65
# 8                                             65
# 9                                             65
# 10                                            65
# 11                                            65
# 12                                            65
# 13                                            65
# 14                                            65
# 15                                            65
# 16                                            65
# 17                                            65
# 18                                            65
# 19                                            65
# 20                                            65
# 21                                            65
# 22                                            65
# 23                                            65
# 24                                            65
# 25                                            65
# 26                                            65
# 27                                            65
# 28                                            65
# 29                                            65
# 30                                            65
# 31                                            65
# 32                                            65
# 33                                            65
# 34                                            65
# 35                                            65
# 36                                            65
# 37                                            65
# 38                                            65
# 39                                            65
# 40                                            65
# 41                                            65
# 42                                            65
# 43                                            65
# 44                                            65
# 45                                            65
# 46                                            65
# 47                                            65
# 48                                            65
# 49                                            65
# 50                                            65
# 51                                            65
# 52                                            65
# 53                                            65
# 54                                            65
# 55                                            65
# 56                                            65
# 57                                            65
# 58                                            65
# 59                                            65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Month                                         60 non-null     datetime64[ns]
#  1   Average Licensed Bed  Occupancy Rate          60 non-null     float64
#  2   Unassisted Fall Rate per 1,000 Patient Days   60 non-null     float64
#  3   Staff Responsiveness Domain Top Box Score     60 non-null     float64
#  4   Unassisted Fall %                             60 non-null     float64
#  5   Staff Responsiveness Domain Top Box Score %   60 non-null     float64
#  6   Staff Responsiveness Top Box Score Benchmark  60 non-null     int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 3.4 KB

# %% [raw]
# Insights: No Missing Values ESC+R+M

# %%
df.describe()
# Out:
#                      Month  Average Licensed Bed  Occupancy Rate  \
# count                   60                             60.000000
# mean   2022-06-16 15:12:00                              0.962167
# min    2020-01-01 00:00:00                              0.810000
# 25%    2021-03-24 06:00:00                              0.950000
# 50%    2022-06-16 00:00:00                              0.960000
# 75%    2023-09-08 12:00:00                              0.980000
# max    2024-12-01 00:00:00                              1.010000
# std                    NaN                              0.028409
#
#        Unassisted Fall Rate per 1,000 Patient Days  \
# count                                    60.000000
# mean                                      2.607833
# min                                       1.030000
# 25%                                       2.310000
# 50%                                       2.590000
# 75%                                       3.030000
# max                                       3.410000
# std                                       0.500712
#
#        Staff Responsiveness Domain Top Box Score  Unassisted Fall %  \
# count                                  60.000000          60.000000
# mean                                   63.087500           0.260783
# min                                    53.310000           0.103000
# 25%                                    60.342500           0.231000
# 50%                                    63.620000           0.259000
# 75%                                    65.992500           0.303000
# max                                    72.750000           0.341000
# std                                     4.148518           0.050071
#
#        Staff Responsiveness Domain Top Box Score %  \
# count                                    60.000000
# mean                                      0.630875
# min                                       0.533100
# 25%                                       0.603425
# 50%                                       0.636200
# 75%                                       0.659925
# max                                       0.727500
# std                                       0.041485
#
#        Staff Responsiveness Top Box Score Benchmark
# count                                          60.0
# mean                                           65.0
# min                                            65.0
# 25%                                            65.0
# 50%                                            65.0
# 75%                                            65.0
# max                                            65.0
# std                                             0.0

# %% [raw]
# 1)The hospital had very high average bed utilization, averaging approximately 96.2% across the dataset.
# 2)Lower = better.(Unassisted Fall Rate per 1,000 Patient Days)
# 3)The average unassisted fall rate was approximately 2.61 per 1,000 patient days.
# 4)Higher responsiveness = better.
# 5)Fall Rate & Fall % These two columns are directly related. We should keep that in mind because we may not need both for every analysis.
# 6)Staff Responsiveness Domain Top Box Score % (Score & Score %)They're the same information represented on different scales
# 7)Staff Responsiveness Top Box Score Benchmark
# 8)Why is EVERYTHING 65?
# 9)Because the benchmark is fixed at 65 for every month Actual responsiveness vs Benchmark72.75 > 65 ✅ above benchmark

# %%
df.isnull().sum()
# Out:
# Month                                           0
# Average Licensed Bed  Occupancy Rate            0
# Unassisted Fall Rate per 1,000 Patient Days     0
# Staff Responsiveness Domain Top Box Score       0
# Unassisted Fall %                               0
# Staff Responsiveness Domain Top Box Score %     0
# Staff Responsiveness Top Box Score Benchmark    0
# dtype: int64

# %%
df.duplicated().sum() #no duplicates in datset
# Out:
# np.int64(0)

# %%
print("Date Range:", df["Month"].dt.date.min(),"to", df["Month"].dt.date.max())
# Out:
# Date Range: 2020-01-01 to 2024-12-01

# %%
df["Month"].nunique() ## To check whether all the "month" values are unique
# Out:
# 60

# %% [raw]
# Insights: The dataset contains 5 years of data from Jan 2020 to Dec 2024

# %%
#rename columns
df.columns=['Month', 'KPI1', 'KPI2', 'KPI3', 'KPI2%', 'KPI3%', 'KPI3_Benchmark']
df.head(2)
# Out:
#        Month  KPI1  KPI2   KPI3  KPI2%   KPI3%  KPI3_Benchmark
# 0 2020-01-01  0.96  2.21  68.34  0.221  0.6834              65
# 1 2020-02-01  0.96  1.79  72.75  0.179  0.7275              65

# %%
df=df.drop(columns=['KPI2%', 'KPI3%', 'KPI3_Benchmark'])
df.head()
# Out:
#        Month  KPI1  KPI2   KPI3
# 0 2020-01-01  0.96  2.21  68.34
# 1 2020-02-01  0.96  1.79  72.75
# 2 2020-03-01  0.81  1.03  67.07
# 3 2020-04-01  0.94  1.97  71.21
# 4 2020-05-01  1.01  3.41  57.68

# %% [markdown]
# ## Exploring KPI1

# %%
# Multiplying the values of KPI by 100 
df["KPI1"] = df["KPI1"]*100

# %%
df
# Out:
#         Month   KPI1  KPI2   KPI3
# 0  2020-01-01   96.0  2.21  68.34
# 1  2020-02-01   96.0  1.79  72.75
# 2  2020-03-01   81.0  1.03  67.07
# 3  2020-04-01   94.0  1.97  71.21
# 4  2020-05-01  101.0  3.41  57.68
# 5  2020-06-01   98.0  2.61  67.86
# 6  2020-07-01   95.0  2.42  66.09
# 7  2020-08-01   94.0  2.09  70.38
# 8  2020-09-01   95.0  3.11  53.31
# 9  2020-10-01   92.0  1.60  67.55
# 10 2020-11-01   95.0  2.31  60.35
# 11 2020-12-01   98.0  2.47  61.33
# 12 2021-01-01  100.0  3.03  61.06
# 13 2021-02-01   99.0  2.35  65.23
# 14 2021-03-01   95.0  2.47  64.02
# 15 2021-04-01   96.0  1.94  70.11
# 16 2021-05-01   94.0  2.54  68.16
# 17 2021-06-01   94.0  3.17  54.38
# 18 2021-07-01   94.0  2.79  64.00
# 19 2021-08-01   93.0  2.05  66.13
# 20 2021-09-01   97.0  3.34  55.17
# 21 2021-10-01   95.0  2.44  64.03
# 22 2021-11-01   96.0  2.31  64.12
# 23 2021-12-01   98.0  2.57  60.42
# 24 2022-01-01  101.0  3.33  58.41
# 25 2022-02-01   99.0  3.19  59.77
# 26 2022-03-01   96.0  2.78  61.32
# 27 2022-04-01   96.0  2.91  60.18
# 28 2022-05-01   95.0  2.49  63.07
# 29 2022-06-01   95.0  2.31  63.11
# 30 2022-07-01   96.0  2.43  61.03
# 31 2022-08-01   96.0  3.13  59.97
# 32 2022-09-01   95.0  2.81  61.53
# 33 2022-10-01   96.0  2.07  64.16
# 34 2022-11-01   97.0  3.11  57.29
# 35 2022-12-01   98.0  3.21  57.18
# 36 2023-01-01   99.0  3.17  58.22
# 37 2023-02-01   99.0  3.39  57.12
# 38 2023-03-01   98.0  3.03  59.45
# 39 2023-04-01   96.0  2.73  62.57
# 40 2023-05-01   94.0  2.89  62.89
# 41 2023-06-01   96.0  2.55  63.69
# 42 2023-07-01   95.0  2.42  64.93
# 43 2023-08-01   95.0  2.03  66.77
# 44 2023-09-01   98.0  2.56  65.96
# 45 2023-10-01   98.0  3.07  60.44
# 46 2023-11-01   99.0  2.99  61.76
# 47 2023-12-01   99.0  3.03  60.32
# 48 2024-01-01   99.0  3.09  60.67
# 49 2024-02-01   98.0  3.15  59.14
# 50 2024-03-01   94.0  2.33  63.55
# 51 2024-04-01   95.0  2.01  66.19
# 52 2024-05-01   95.0  1.79  67.01
# 53 2024-06-01   95.0  1.98  66.53
# 54 2024-07-01   96.0  2.51  65.87
# 55 2024-08-01   96.0  2.63  65.46
# 56 2024-09-01   97.0  2.71  65.71
# 57 2024-10-01   98.0  2.97  64.02
# 58 2024-11-01   98.0  2.84  64.13
# 59 2024-12-01  100.0  2.81  65.08

# %%
# Summary of KPI1
df["KPI1"].describe()
# Out:
# count     60.000000
# mean      96.216667
# std        2.840934
# min       81.000000
# 25%       95.000000
# 50%       96.000000
# 75%       98.000000
# max      101.000000
# Name: KPI1, dtype: float64

# %%
# Boxplot of KPI1
plt.figure(figsize=(8,5))
sns.boxplot(y=df["KPI1"])
plt.title("Box Plot of Average Licensed Bed  Occupancy Rate")
plt.ylabel("Average Licensed Bed  Occupancy Rate")
plt.show()

# %% [raw]
# The boxplot helps us visually identify values that are unusually high or low compared with the rest of the data.
#
# In the dataset, most occupancy values are around 95–98%, while the minimum is 81% and maximum is 101%.
# So investigate how 81% appears on  boxplot.

# %%
df[df["KPI1"] <  90]
# Out:
#        Month  KPI1  KPI2   KPI3
# 2 2020-03-01  81.0  1.03  67.07

# %% [raw]
# Insights: There is only one outlier where KPI1 = 81

# %% [markdown]
# ## Exploring KPI2

# %%
# Summary of KPI2
df["KPI2"].describe()
# Out:
# count    60.000000
# mean      2.607833
# std       0.500712
# min       1.030000
# 25%       2.310000
# 50%       2.590000
# 75%       3.030000
# max       3.410000
# Name: KPI2, dtype: float64

# %%
# Boxplot of KPI2
plt.figure(figsize=(8,5))
sns.boxplot(y=df["KPI2"])
plt.title("Box Plot of Unassisted Fall Rate per 1,000 Patient Days")
plt.ylabel("Unassisted Fall Rate per 1,000 Patient Days")
plt.show()

# %%
df[df["KPI2"] <  1.5]
# Out:
#        Month  KPI1  KPI2   KPI3
# 2 2020-03-01  81.0  1.03  67.07

# %% [raw]
# Insights: There is only one outlier where KPI2 = 1.03. It is the same record for which the KPI1 value is the outlier.
# In the month of March, 2020 both KPI1 and KPI2 are outliers.

# %% [markdown]
# ## Exploring KPI3

# %%
# Summary of KPI3
df["KPI2"].describe()
# Out:
# count    60.000000
# mean      2.607833
# std       0.500712
# min       1.030000
# 25%       2.310000
# 50%       2.590000
# 75%       3.030000
# max       3.410000
# Name: KPI2, dtype: float64

# %%
# Boxplot of KPI3
plt.figure(figsize=(8,5))
sns.boxplot(y=df["KPI3"])
plt.title("Box Plot of Staff Responsiveness Domain Top Box Score ")
plt.ylabel("Staff Responsiveness Domain Top Box Score")
plt.show()

# %% [raw]
# Insights: No outliers

# %% [markdown]
# # Investigating relationship between the KPIs

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df)
plt.show()

# %% [raw]
# Causation:One thing directly causes another thing to happen.
# ex:.Patient presses call button → nurse comes to help.
# The call/request caused the response.
#
#  Correlation = two things move together.
# Causation = one thing makes the other happen.above is example
#
# ❌ “High bed occupancy causes patients to fall.”
# We can say:
# ✅Higher bed occupancy is associated with higher unassisted fall rates.
#
# Because other things could affect falls too—staffing levels, patient condition, time of day, etc.—and those factors aren't provided in this dataset.

# %% [raw]
# Initial observation: Higher bed occupancy appears to be associated with higher unassisted fall rates.
# Higher fall rates are also associated with lower staff responsiveness.
# the strongest visual relationship appears to be between unassisted falls and staff responsiveness.

# %%
plt.figure(figsize=(8,5))                              #KPI1 = Bed Occupancy Rate
                                                       #KPI2 = Unassisted Fall Rate
                                                       #KPI3 = Staff Responsiveness Score
sns.scatterplot(
    x=df["KPI1"],
    y=df["KPI2"]
)

plt.title("KPI1 vs KPI2")
plt.xlabel("KPI1")
plt.ylabel("KPI2")

plt.show()

# %%
print(df[["KPI1", "KPI2", "KPI3"]].corr())
# Out:
#           KPI1      KPI2      KPI3
# KPI1  1.000000  0.700112 -0.371821
# KPI2  0.700112  1.000000 -0.791340
# KPI3 -0.371821 -0.791340  1.000000

# %%
sns.heatmap(df[["KPI1", "KPI2", "KPI3"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.savefig("KPI_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [raw]
# The heatmap shows that higher bed occupancy is associated with higher unassisted fall rates.
# It also shows that better staff responsiveness is strongly associated with lower fall rates.
# The strongest relationship is between staff responsiveness and unassisted falls, with a correlation of -0.79.

# %%
1. Bed Occupancy vs Fall Rate = +0.70
This is a strong positive relationship.
 When bed occupancy increases, unassisted fall rates tend to increase.

2. Bed Occupancy vs Staff Responsiveness = -0.37
This is a weaker negative relationship.
 When bed occupancy increases, staff responsiveness tends to decrease somewhat.

3.Fall Rate vs Staff Responsiveness = -0.79 ⭐
This is the strongest relationship in the heatmap.
When staff responsiveness is higher, unassisted fall rates tend to be lower.

# %% [raw]
# | Absolute correlation | Interpretation |
# | -------------------: | -------------- |
# |        `0.00 – 0.29` | Weak           |
# |        `0.30 – 0.59` | Moderate       |
# |        `0.60 – 1.00` | Strong         |
#
#
# +0.70 → Strong positive
# Because 0.70 is between 0.60–1.00.
# Meaning:
# Occupancy ↑ → Falls ↑
#
# -0.37 → Moderate negative
# Ignore the minus temporarily and look at 0.37. It's between 0.30–0.59.
# Meaning:
# Occupancy ↑ → Responsiveness ↓
#
# -0.79 → Strong negative
# Ignore the minus temporarily: 0.79 is between 0.60–1.00.
#
# Meaning:
# Responsiveness ↑ → Falls ↓
#
# One note: there isn't one universal cutoff for “weak/moderate/strong”; different fields use different conventions. The ranges above are a simple convention you can use consistently for this project.

# %% [raw]
# Summary of Key Relationships:
# Higher bed occupancy is associated with higher fall rates and slightly lower staff responsiveness. Hospitals may need to
# ensure that higher occupancy does not overwhelm staff, potentially compromising patient safety and care.
# Better staff responsiveness is strongly associated with fewer falls, indicating that when staff are more responsive,
# patient safety improves, and falls are reduced.

# %% [markdown]
# # Trends in KPIs over time

# %% [markdown]
# ## KPI1

# %%
# KPI1 vs Time
# Set figure size
plt.figure(figsize=(12, 6))

# Line plot
sns.lineplot(data=df, x="Month", y="KPI1", color="royalblue", linewidth=2)

# Labels & Title
plt.xlabel("Date", fontsize=12, fontweight="bold")
plt.ylabel("Average Licensed Bed  Occupancy Rate", fontsize=12, fontweight="bold")
plt.title("Average Licensed Bed  Occupancy Rate Trend Over Time", fontsize=14, fontweight="bold", color="red")

# Format x-axis to show Month-Year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))  # Jan-2010 format
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))  # Show every 2nd month

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Set x-axis limits to start from the first date in the dataset
plt.xlim(df["Month"].min(), df["Month"].max())

# Show grid for better readability
plt.grid(True, linestyle="--", alpha=0.5)

# Show plot
plt.show()

# %% [raw]
# Insight:Bed occupancy remained consistently high throughout 2020–2024,
# generally around 94–100%, with one significant drop to 81% in early 2020.

# %%
# KPI1 by month

# %%
# Extract month name
df["Month_Name"] = df["Month"].dt.month_name()

# Aggregate KPI1 by month (averaging values)
kpi1_by_month = df.groupby("Month_Name")["KPI1"].mean()                     # So Python combined all 5 Januaries and averaged them, 
                                                                            #all 5 Februaries and averaged them, and so on.

# Sort months in order (Jan–Dec)
month_order = [
    "January", "February", "March", "April", "May", "June", 
    "July", "August", "September", "October", "November", "December"
]
kpi1_by_month = kpi1_by_month.reindex(month_order)
kpi1_by_month
# Out:
# Month_Name
# January      99.0
# February     98.2
# March        92.8
# April        95.4
# May          95.8
# June         95.6
# July         95.2
# August       94.8
# September    96.4
# October      95.8
# November     97.0
# December     98.6
# Name: KPI1, dtype: float64

# %%
# Plot KPI1 by Month
plt.figure(figsize=(10, 5))
sns.lineplot(x=kpi1_by_month.index, y=kpi1_by_month.values, color="royalblue")

# Formatting
plt.xlabel("Month", fontsize=12, fontweight="bold")
plt.ylabel("Average Licensed Bed  Occupancy Rate", fontsize=12, fontweight="bold")
plt.title("Average Licensed Bed  Occupancy Rate by Month", fontsize=14, fontweight="bold", color="red")

# Set x-axis limits to start from the first date in the dataset
plt.xlim("January", "December")

plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %%
df[df["Month_Name"] == "March"][["Month", "KPI1"]]
# Out:
#         Month  KPI1
# 2  2020-03-01  81.0
# 14 2021-03-01  95.0
# 26 2022-03-01  96.0
# 38 2023-03-01  98.0
# 50 2024-03-01  94.0

# %% [raw]
# I noticed that March had unusually low average occupancy.
# I drilled into the monthly records and found that this was mainly driven by an 81% occupancy observation in March 2020,
# while March occupancy in the other years was between 94% and 98%.

# %%
# Extract year name
df["year"] = df["Month"].dt.year

# Aggregate KPI1 by month (averaging values)
kpi1_by_year = round(df.groupby("year")["KPI1"].mean(), 3)

# Reset index
#kpi1_by_year = kpi1_by_year.reset_index()
kpi1_by_year
# Out:
# year
# 2020    94.583
# 2021    95.917
# 2022    96.667
# 2023    97.167
# 2024    96.750
# Name: KPI1, dtype: float64

# %%
plt.figure(figsize=(10, 4))

# Bar plot with thinner bars
sns.barplot(x=kpi1_by_year.index, y=kpi1_by_year.values, palette="pastel", width=0.5)  # Decrease width to make bars thinner

# Adjust Y-axis limits to zoom in on variations
plt.ylim(kpi1_by_year.min() * 0.96, kpi1_by_year.max() * 1.01)

# Formatting
plt.xlabel("Year", fontsize=12)
plt.ylabel("Average Licensed Bed Occupancy Rate", fontsize=12)
plt.title("Average Licensed Bed Occupancy Rate by Year", fontsize=14, fontweight="bold", color="red")

# Add values on top of bars
for i, value in enumerate(kpi1_by_year.values):
    plt.text(i, value - 2, f"{value:.1f}", ha="center", fontsize=10, fontweight="bold")

# Improve x-axis readability
plt.xticks(rotation=45)

# Add a grid for better comparison
plt.grid(axis="y", linestyle="--", alpha=0.5)

# Save the figure
plt.savefig("KPI1_plot.png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# C:\Users\majaz\AppData\Local\Temp\ipykernel_25072\456949411.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=kpi1_by_year.index, y=kpi1_by_year.values, palette="pastel", width=0.5)  # Decrease width to make bars thinner

# %%
INSITE:Occupancy being around 95–97% tells us the hospital was operating with very high bed utilization.

# %% [markdown]
# ## KPI2

# %%
# KPI2 vs Time
# Set figure size
plt.figure(figsize=(12, 6))

# Line plot
sns.lineplot(data=df, x="Month", y="KPI2", color="royalblue", linewidth=2)

# Labels & Title
plt.xlabel("Date", fontsize=12, fontweight="bold")
plt.ylabel("Unassisted Fall Rate per 1,000 Patient Days", fontsize=12, fontweight="bold")
plt.title("Unassisted Fall Rate per 1,000 Patient Days", fontsize=14, fontweight="bold", color="red")

# Format x-axis to show Month-Year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))  # Jan-2010 format
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))  # Show every 2nd month

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Set x-axis limits to start from the first date in the dataset
plt.xlim(df["Month"].min(), df["Month"].max())

# Show grid for better readability
plt.grid(True, linestyle="--", alpha=0.5)

# Show plot
plt.show()

# %%
#KPI2 by month

# %%
# Extract month name
df["Month_Name"] = df["Month"].dt.month_name()

# Aggregate KPI1 by month (averaging values)
kpi2_by_month = df.groupby("Month_Name")["KPI2"].mean()

# Sort months in order (Jan–Dec)
month_order = [
    "January", "February", "March", "April", "May", "June", 
    "July", "August", "September", "October", "November", "December"
]
kpi2_by_month = kpi2_by_month.reindex(month_order)
kpi2_by_month
# Out:
# Month_Name
# January      2.966
# February     2.774
# March        2.328
# April        2.312
# May          2.624
# June         2.524
# July         2.514
# August       2.386
# September    2.906
# October      2.430
# November     2.712
# December     2.818
# Name: KPI2, dtype: float64

# %%
# Plot KPI2 by Month
plt.figure(figsize=(10, 5))
sns.lineplot(x=kpi2_by_month.index, y=kpi2_by_month.values, color="royalblue")

# Formatting
plt.xlabel("Month", fontsize=12, fontweight="bold")
plt.ylabel("Unassisted Fall Rate per 1,000 Patient Days", fontsize=12, fontweight="bold")
plt.title("Unassisted Fall Rate per 1,000 Patient Days by Month", fontsize=14, fontweight="bold", color="red")

# Set x-axis limits to start from the first date in the dataset
plt.xlim("January", "December")

plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %% [raw]
# January had one of the highest average occupancy levels (~99%).
# January also has the highest average fall rate (~2.97).
# That fits with our earlier correlation result:
# Occupancy ↑ → Falls ↑ (r = +0.70)

# %%
# KPI2 by year
# Extract year name
df["year"] = df["Month"].dt.year

# Aggregate KPI2 by month (averaging values)
kpi2_by_year = round(df.groupby("year")["KPI2"].mean(), 2)

# Reset index
kpi2_by_year
# Out:
# year
# 2020    2.25
# 2021    2.58
# 2022    2.81
# 2023    2.82
# 2024    2.57
# Name: KPI2, dtype: float64

# %%
print(round(kpi2_by_year.mean(),2))
# Out:
# 2.61

# %%
plt.figure(figsize=(10, 4))

# Bar plot with thinner bars
sns.barplot(x=kpi2_by_year.index, y=kpi2_by_year.values, palette="pastel", width=0.5)  # Decrease width to make bars thinner

# Adjust Y-axis limits to zoom in on variations
#plt.ylim(kpi2_by_year.min() * 0.96, kpi2_by_year.max() * 1.01)

# Formatting
plt.xlabel("Year", fontsize=12)
plt.ylabel("Unassisted Fall Rate per 1,000 Patient Days", fontsize=12)
plt.title("Unassisted Fall Rate per 1,000 Patient Days by Year", fontsize=14, fontweight="bold", color="red")

# Add values on top of bars
for i, value in enumerate(kpi2_by_year.values):
    plt.text(i, value - 0.8, f"{value:.1f}", ha="center", fontsize=10, fontweight="bold")

# Improve x-axis readability
plt.xticks(rotation=45)

# Add a grid for better comparison
plt.grid(axis="y", linestyle="--", alpha=0.5)

# Save the figure
plt.savefig("KPI2_plot.png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# C:\Users\majaz\AppData\Local\Temp\ipykernel_25072\105981411.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=kpi2_by_year.index, y=kpi2_by_year.values, palette="pastel", width=0.5)  # Decrease width to make bars thinner

# %% [raw]
# The average unassisted fall rate increased from 2020 through 2022–2023, then improved in 2024.

# %% [markdown]
# ## KPI3

# %%
# KPI3 vs Time
# Set figure size
plt.figure(figsize=(12, 6))

# Line plot
sns.lineplot(data=df, x="Month", y="KPI3", color="royalblue", linewidth=2)

# Labels & Title
plt.xlabel("Date", fontsize=12, fontweight="bold")
plt.ylabel("Staff Responsiveness Top Box Score", fontsize=12, fontweight="bold")
plt.title("Staff Responsiveness Top Box Score", fontsize=14, fontweight="bold", color="red")

# Format x-axis to show Month-Year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))  # Jan-2010 format
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))  # Show every 2nd month

# Rotate x-axis labels for better readability
plt.xticks(rotation=50)

# Set x-axis limits to start from the first date in the dataset
plt.xlim(df["Month"].min(), df["Month"].max())

# Show grid for better readability
plt.grid(True, linestyle="--", alpha=0.5)

# Show plot
plt.show()

# %%
# KPI3 by month
# Extract month name
df["Month_Name"] = df["Month"].dt.month_name()

# Aggregate KPI3 by month (averaging values)
kpi3_by_month = df.groupby("Month_Name")["KPI3"].mean()

# Sort months in order (Jan–Dec)
month_order = [
    "January", "February", "March", "April", "May", "June", 
    "July", "August", "September", "October", "November", "December"
]
kpi3_by_month = kpi3_by_month.reindex(month_order)
kpi3_by_month
# Out:
# Month_Name
# January      61.340
# February     62.802
# March        63.082
# April        66.052
# May          63.762
# June         63.114
# July         64.384
# August       65.742
# September    60.336
# October      64.040
# November     61.530
# December     60.866
# Name: KPI3, dtype: float64

# %%
# Plot KPI3 by Month
plt.figure(figsize=(10, 5))
sns.lineplot(x=kpi3_by_month.index, y=kpi3_by_month.values, color="royalblue")

# Formatting
plt.xlabel("Month", fontsize=12, fontweight="bold")
plt.ylabel("Staff Responsiveness Top Box Score", fontsize=12, fontweight="bold")
plt.title("Staff Responsiveness Top Box Score by Month", fontsize=14, fontweight="bold", color="red")

# Set x-axis limits to start from the first date in the dataset
plt.xlim("January", "December")

plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %%
# KPI3 by year
# Extract year name
df["year"] = df["Month"].dt.year

# Aggregate KPI3 by month (averaging values)
kpi3_by_year = round(df.groupby("year")["KPI3"].mean(), 2)

# Reset index
kpi3_by_year
# Out:
# year
# 2020    65.33
# 2021    63.07
# 2022    60.58
# 2023    62.01
# 2024    64.45
# Name: KPI3, dtype: float64

# %%
plt.figure(figsize=(10, 4))

# Bar plot with thinner bars
sns.barplot(x=kpi3_by_year.index, y=kpi3_by_year.values, palette="pastel", width=0.5)  # Decrease width to make bars thinner

# Adjust Y-axis limits to zoom in on variations
plt.ylim(kpi3_by_year.min() * 0.96, kpi3_by_year.max() * 1.01)

# Formatting
plt.xlabel("Year", fontsize=12)
plt.ylabel("Staff Responsiveness Top Box Score", fontsize=12)
plt.title("Staff Responsiveness Top Box Score by Year", fontsize=14, fontweight="bold", color="red")

# Add values on top of bars
for i, value in enumerate(kpi3_by_year.values):
    plt.text(i, value - 0.8, f"{value:.1f}", ha="center", fontsize=10, fontweight="bold")

# Improve x-axis readability
plt.xticks(rotation=45)

# Add a grid for better comparison
plt.grid(axis="y", linestyle="--", alpha=0.5)

# Save the figure
plt.savefig("KPI3_plot.png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# C:\Users\majaz\AppData\Local\Temp\ipykernel_25072\1473535158.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=kpi3_by_year.index, y=kpi3_by_year.values, palette="pastel", width=0.5)  # Decrease width to make bars thinner

# %% [raw]
# 1. Average Licensed Bed Occupancy Rate (KPI1)
# Your hospital: 96.22%
# U.S. benchmark: ~66%
# Inference:
# Your hospital has a significantly higher occupancy rate than the national average.
# This could indicate strong patient demand, efficient utilization of beds, or potential capacity issues.
# A consistently high occupancy rate above 85% might lead to overcrowding, strain on staff, and reduced patient satisfaction.
#
# 2. Unassisted Fall Rate per 1,000 Patient Days (KPI2)
# Your hospital: 2.61 falls per 1,000 patient days
# Benchmark: 2.3 – 13 falls per 1,000 patient days
# Inference:
# Your hospital's fall rate is on the lower end of the national range, which is a positive sign.
# It suggests good patient safety measures and fall prevention protocols.
# However, continuous monitoring is essential to prevent increases, especially with high bed occupancy.
#
# 3. Staff Responsiveness Domain Top Box Score (KPI3)
# Your hospital: 63.09%
# Benchmark: 85% – 90%
# Inference:
# Your staff responsiveness score is below industry standards, which may indicate delays in addressing patient needs.
# The high bed occupancy rate (KPI1) could be a contributing factor, as staff might be overwhelmed.
# Improving staffing levels, response times, and communication could help boost this metric.
#
# Final Assessment
# High Bed Occupancy (KPI1) and Low Staff Responsiveness (KPI3) suggest potential operational strain.
# Despite high occupancy, fall prevention efforts (KPI2) appear effective.
# Improving staff responsiveness may enhance patient satisfaction and overall hospital efficiency.

# %%
df.to_csv("hospital_cleaned_data.csv", index=False)

# %%
df
# Out:
#         Month   KPI1  KPI2   KPI3 Month_Name  year
# 0  2020-01-01   96.0  2.21  68.34    January  2020
# 1  2020-02-01   96.0  1.79  72.75   February  2020
# 2  2020-03-01   81.0  1.03  67.07      March  2020
# 3  2020-04-01   94.0  1.97  71.21      April  2020
# 4  2020-05-01  101.0  3.41  57.68        May  2020
# 5  2020-06-01   98.0  2.61  67.86       June  2020
# 6  2020-07-01   95.0  2.42  66.09       July  2020
# 7  2020-08-01   94.0  2.09  70.38     August  2020
# 8  2020-09-01   95.0  3.11  53.31  September  2020
# 9  2020-10-01   92.0  1.60  67.55    October  2020
# 10 2020-11-01   95.0  2.31  60.35   November  2020
# 11 2020-12-01   98.0  2.47  61.33   December  2020
# 12 2021-01-01  100.0  3.03  61.06    January  2021
# 13 2021-02-01   99.0  2.35  65.23   February  2021
# 14 2021-03-01   95.0  2.47  64.02      March  2021
# 15 2021-04-01   96.0  1.94  70.11      April  2021
# 16 2021-05-01   94.0  2.54  68.16        May  2021
# 17 2021-06-01   94.0  3.17  54.38       June  2021
# 18 2021-07-01   94.0  2.79  64.00       July  2021
# 19 2021-08-01   93.0  2.05  66.13     August  2021
# 20 2021-09-01   97.0  3.34  55.17  September  2021
# 21 2021-10-01   95.0  2.44  64.03    October  2021
# 22 2021-11-01   96.0  2.31  64.12   November  2021
# 23 2021-12-01   98.0  2.57  60.42   December  2021
# 24 2022-01-01  101.0  3.33  58.41    January  2022
# 25 2022-02-01   99.0  3.19  59.77   February  2022
# 26 2022-03-01   96.0  2.78  61.32      March  2022
# 27 2022-04-01   96.0  2.91  60.18      April  2022
# 28 2022-05-01   95.0  2.49  63.07        May  2022
# 29 2022-06-01   95.0  2.31  63.11       June  2022
# 30 2022-07-01   96.0  2.43  61.03       July  2022
# 31 2022-08-01   96.0  3.13  59.97     August  2022
# 32 2022-09-01   95.0  2.81  61.53  September  2022
# 33 2022-10-01   96.0  2.07  64.16    October  2022
# 34 2022-11-01   97.0  3.11  57.29   November  2022
# 35 2022-12-01   98.0  3.21  57.18   December  2022
# 36 2023-01-01   99.0  3.17  58.22    January  2023
# 37 2023-02-01   99.0  3.39  57.12   February  2023
# 38 2023-03-01   98.0  3.03  59.45      March  2023
# 39 2023-04-01   96.0  2.73  62.57      April  2023
# 40 2023-05-01   94.0  2.89  62.89        May  2023
# 41 2023-06-01   96.0  2.55  63.69       June  2023
# 42 2023-07-01   95.0  2.42  64.93       July  2023
# 43 2023-08-01   95.0  2.03  66.77     August  2023
# 44 2023-09-01   98.0  2.56  65.96  September  2023
# 45 2023-10-01   98.0  3.07  60.44    October  2023
# 46 2023-11-01   99.0  2.99  61.76   November  2023
# 47 2023-12-01   99.0  3.03  60.32   December  2023
# 48 2024-01-01   99.0  3.09  60.67    January  2024
# 49 2024-02-01   98.0  3.15  59.14   February  2024
# 50 2024-03-01   94.0  2.33  63.55      March  2024
# 51 2024-04-01   95.0  2.01  66.19      April  2024
# 52 2024-05-01   95.0  1.79  67.01        May  2024
# 53 2024-06-01   95.0  1.98  66.53       June  2024
# 54 2024-07-01   96.0  2.51  65.87       July  2024
# 55 2024-08-01   96.0  2.63  65.46     August  2024
# 56 2024-09-01   97.0  2.71  65.71  September  2024
# 57 2024-10-01   98.0  2.97  64.02    October  2024
# 58 2024-11-01   98.0  2.84  64.13   November  2024
# 59 2024-12-01  100.0  2.81  65.08   December  2024

# %%
df.to_csv(
    r"C:\Users\majaz\OneDrive\Desktop\Hospital_project\hospital_cleaned_data.csv",
    index=False
)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\majaz'
